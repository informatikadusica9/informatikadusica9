# %%
import pandas as pd

# %%
Rezultati = [["1", "Una",    "Zorić",      "Ž", 161, 45, 16.32, 1.21, 25],
             ["2", "Marta",  "Stanojević", "Ž", 165, 53, 15.44, 1.01, 16],
             ["3", "Ognjen", "Novaković",  "M", 171, 64, 14.56, 1.10, 5],
             ["4", "Petra",  "Kaličanin",  "Ž", 159, 48, 16.98, 0.89, 21],
             ["5", "Novak",  "Đorđević",   "M", 175, 67, 15.01, 1.32, 28],
             ["6", "Đurđe",  "Martać",     "M", 178, 65, 16.25, 1.18, 25],
             ["7", "Kalina", "Ognjenović", "Ž", 170, 62, 14.38, 0.95, 25],
             ["8", "Vanja",  "Čolović",    "M", 181, 72, 14.55, 0.98, 26]]

# %%
T = pd.DataFrame(Rezultati)
T.columns = ["R. br.", "Ime", "Prezime", "Pol", "Visina", 
                          "Težina", "Trka100m", "Skok udalj", "Čučnjevi"]

# %% [markdown]
# #**iloc - označavanje delova tabele po indexima

# %% [markdown]
# #Označavanje cele tabele - svih 8 redova i 9 kolona

# %%
T.iloc[0:?,0:?]
# Out:
#   R. br.     Ime     Prezime Pol  Visina  Težina  Trka100m  Skok udalj  \
# 0      1     Una       Zorić   Ž     161      45     16.32        1.21
# 1      2   Marta  Stanojević   Ž     165      53     15.44        1.01
# 2      3  Ognjen   Novaković   M     171      64     14.56        1.10
# 3      4   Petra   Kaličanin   Ž     159      48     16.98        0.89
# 4      5   Novak    Đorđević   M     175      67     15.01        1.32
# 5      6   Đurđe      Martać   M     178      65     16.25        1.18
# 6      7  Kalina  Ognjenović   Ž     170      62     14.38        0.95
# 7      8   Vanja     Čolović   M     181      72     14.55        0.98
#
#    Čučnjevi
# 0        25
# 1        16
# 2         5
# 3        21
# 4        28
# 5        25
# 6        25
# 7        26

# %%
#Vezbanje sa str 179 - označi sve redove i kolone od 5 do 9 u promenljivu Poslednjih 6 skokova

# %%
Poslednjih5kolona=T.iloc[?,?:?]
Poslednjih5kolona
# Out:
#    Visina  Težina  Trka100m  Skok udalj  Čučnjevi
# 0     161      45     16.32        1.21        25
# 1     165      53     15.44        1.01        16
# 2     171      64     14.56        1.10         5
# 3     159      48     16.98        0.89        21
# 4     175      67     15.01        1.32        28
# 5     178      65     16.25        1.18        25
# 6     170      62     14.38        0.95        25
# 7     181      72     14.55        0.98        26

# %% [markdown]
# # svi primeri sa strane 179

# %%
#svi redovi i kolone

# %%
T.iloc[??]
# Out:
#   R. br.     Ime     Prezime Pol  Visina  Težina  Trka100m  Skok udalj  \
# 0      1     Una       Zorić   Ž     161      45     16.32        1.21
# 1      2   Marta  Stanojević   Ž     165      53     15.44        1.01
# 2      3  Ognjen   Novaković   M     171      64     14.56        1.10
# 3      4   Petra   Kaličanin   Ž     159      48     16.98        0.89
# 4      5   Novak    Đorđević   M     175      67     15.01        1.32
# 5      6   Đurđe      Martać   M     178      65     16.25        1.18
# 6      7  Kalina  Ognjenović   Ž     170      62     14.38        0.95
# 7      8   Vanja     Čolović   M     181      72     14.55        0.98
#
#    Čučnjevi
# 0        25
# 1        16
# 2         5
# 3        21
# 4        28
# 5        25
# 6        25
# 7        26

# %%
#Сви редови од реда с индексом 2 и све колоне од колоне с индексом 2 (редови од 3. реда и колоне од 3. колоне)

# %%
T.iloc[?:,?:]
# Out:
#       Prezime Pol  Visina  Težina  Trka100m  Skok udalj  Čučnjevi
# 2   Novaković   M     171      64     14.56        1.10         5
# 3   Kaličanin   Ž     159      48     16.98        0.89        21
# 4    Đorđević   M     175      67     15.01        1.32        28
# 5      Martać   M     178      65     16.25        1.18        25
# 6  Ognjenović   Ž     170      62     14.38        0.95        25
# 7     Čolović   M     181      72     14.55        0.98        26

# %%
#Сви редови до реда с индексом 4 и све колоне до колоне с индексом 4(првих 5 редова и првих 5 колона)

# %%
T.iloc[:?,:?]
# Out:
#   R. br.     Ime     Prezime Pol  Visina
# 0      1     Una       Zorić   Ž     161
# 1      2   Marta  Stanojević   Ž     165
# 2      3  Ognjen   Novaković   M     171
# 3      4   Petra   Kaličanin   Ž     159
# 4      5   Novak    Đorđević   M     175

# %%
#Сви редови и колоне од колоне с индексом 4 до колоне с индексом 7 (колоне од 5. до 8)

# %%
T.iloc[:,?:?]
# Out:
#    Visina  Težina  Trka100m  Skok udalj
# 0     161      45     16.32        1.21
# 1     165      53     15.44        1.01
# 2     171      64     14.56        1.10
# 3     159      48     16.98        0.89
# 4     175      67     15.01        1.32
# 5     178      65     16.25        1.18
# 6     170      62     14.38        0.95
# 7     181      72     14.55        0.98

# %%
#Редови од реда с индексом 2 до реда с индексом 5 (редови од 3. до 6.) и све колоне

# %%
TabelaRezultata.iloc[?:?,:]
# Out:
#   R. br.     Ime    Prezime Pol  Visina  Težina  Trka100m  Skok udalj  \
# 2      3  Ognjen  Novaković   M     171      64     14.56        1.10
# 3      4   Petra  Kaličanin   Ž     159      48     16.98        0.89
# 4      5   Novak   Đorđević   M     175      67     15.01        1.32
# 5      6   Đurđe     Martać   M     178      65     16.25        1.18
#
#    Čučnjevi
# 2         5
# 3        21
# 4        28
# 5        25

# %%
#Сви редови и колоне с индексима 1,4 и 6 (2,4. и 7. колона)

# %%
T.iloc[:,[?,?,?]]
# Out:
#       Ime  Visina  Trka100m
# 0     Una     161     16.32
# 1   Marta     165     15.44
# 2  Ognjen     171     14.56
# 3   Petra     159     16.98
# 4   Novak     175     15.01
# 5   Đurđe     178     16.25
# 6  Kalina     170     14.38
# 7   Vanja     181     14.55

# %%
#Сваки други ред и свака трећа колона од почетка табеле

# %%
T.iloc[?::?,?::?]
# Out:
#   R. br. Pol  Trka100m
# 0      1   Ž     16.32
# 2      3   M     14.56
# 4      5   M     15.01
# 6      7   Ž     14.38

# %%
#Сваки други ред и свака трећа колона почевши од реда и колоне с индексима 4 (од 5. реда и 5. колоне)

# %%
T.iloc[?::?,?::?]
# Out:
#    Visina  Skok udalj
# 4     175        1.32
# 6     170        0.95

# %%
#Сви редови осим последњих 5 редова и последњих 5 колона

# %%
T.iloc[:?,?:]
# Out:
#    Visina  Težina  Trka100m  Skok udalj  Čučnjevi
# 0     161      45     16.32        1.21        25
# 1     165      53     15.44        1.01        16
# 2     171      64     14.56        1.10         5

# %%
#Последњих 5 редова и све колоне осим последњих 5

# %%
T.iloc[?:,:?]
# Out:
#   R. br.     Ime     Prezime Pol
# 3      4   Petra   Kaličanin   Ž
# 4      5   Novak    Đorđević   M
# 5      6   Đurđe      Martać   M
# 6      7  Kalina  Ognjenović   Ž
# 7      8   Vanja     Čolović   M

# %% [markdown]
# #**loc - označavanje delova tabele po koloni koja ima stringove(tekst)

# %% [markdown]
# #**indeksiranje je postavljanje neke kolone umesto indexa naredbom set_index

# %%
T.???("Ime", inplace=True)

# %%
T
# Out:
#        R. br.     Prezime Pol  Visina  Težina  Trka100m  Skok udalj  Čučnjevi
# Ime
# Una         1       Zorić   Ž     161      45     16.32        1.21        25
# Marta       2  Stanojević   Ž     165      53     15.44        1.01        16
# Ognjen      3   Novaković   M     171      64     14.56        1.10         5
# Petra       4   Kaličanin   Ž     159      48     16.98        0.89        21
# Novak       5    Đorđević   M     175      67     15.01        1.32        28
# Đurđe       6      Martać   M     178      65     16.25        1.18        25
# Kalina      7  Ognjenović   Ž     170      62     14.38        0.95        25
# Vanja       8     Čolović   M     181      72     14.55        0.98        26

# %% [markdown]
# #Označavanje cele tabele po imenima - svih 8 redova i 9 kolona

# %%
T.loc["?":"Vanja","?":"Čučnjevi"]
# Out:
#        R. br.     Prezime Pol  Visina  Težina  Trka100m  Skok udalj  Čučnjevi
# Ime
# Una         1       Zorić   Ž     161      45     16.32        1.21        25
# Marta       2  Stanojević   Ž     165      53     15.44        1.01        16
# Ognjen      3   Novaković   M     171      64     14.56        1.10         5
# Petra       4   Kaličanin   Ž     159      48     16.98        0.89        21
# Novak       5    Đorđević   M     175      67     15.01        1.32        28
# Đurđe       6      Martać   M     178      65     16.25        1.18        25
# Kalina      7  Ognjenović   Ž     170      62     14.38        0.95        25
# Vanja       8     Čolović   M     181      72     14.55        0.98        26

# %%
#vezbanje sa str 181 izdvoj ćeliju sa čučnjevima Marte

# %%
T.loc["?","?"]
# Out:
# 16

# %% [markdown]
# #Svi podaci Marte - iz svih kolona

# %%
T.loc["?"]
# Out:
# R. br.                 2
# Prezime       Stanojević
# Pol                    Ž
# Visina               165
# Težina                53
# Trka100m           15.44
# Skok udalj          1.01
# Čučnjevi              16
# Name: Marta, dtype: object

# %% [markdown]
# #samo određene kolone i svi njihovi redovi

# %%
T.loc[:,["?","?","?"]]
# Out:
#        R. br.     Prezime  Čučnjevi
# Ime
# Una         1       Zorić        25
# Marta       2  Stanojević        16
# Ognjen      3   Novaković         5
# Petra       4   Kaličanin        21
# Novak       5    Đorđević        28
# Đurđe       6      Martać        25
# Kalina      7  Ognjenović        25
# Vanja       8     Čolović        26

# %% [markdown]
# #svaki druga vrsta i svaka treća kolona

# %%
T.loc["?":"?":2,"?":"?":3]
# Out:
#        R. br.  Visina  Skok udalj
# Ime
# Una         1     161        1.21
# Ognjen      3     171        1.10
# Novak       5     175        1.32
# Kalina      7     170        0.95
