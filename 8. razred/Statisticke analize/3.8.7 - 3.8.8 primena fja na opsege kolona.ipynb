# %%
import pandas as pd

# %%
Rezultati = [["1", "Una",    "Zorić",      "Ž", 161, 45, 16.32, 1.21, 25],
             ["2", "Marta",  "Stanojević", "Ž", 165, 53, 15.44, 1.01, 16],
             ["3", "Ognjen", "Novaković",  "M", 171, 64, 14.56, 1.10, 5],
             ["4", "Petra",  "Kaličanin",  "Ž", 159, 48, 16.98, 0.89, 21],
             ["5", "Novak",  "Đorđević",   "M", 175, 67, 15.01, 1.32, 28],
             ["6", "Đurđe",  "Martać",     "M", 178, 65, 16.25, 1.18, 25],
             ["7", "Kalina", "Ognjenović", "Ž", 170, 62, 14.38, 0.95, 25],
             ["8", "Vanja",  "Čolović",    "M", 181, 72, 14.55, 0.98, 26]]

# %%
TabelaRezultata = pd.DataFrame(Rezultati)
TabelaRezultata.columns = ["R. br.", "Ime", "Prezime", "Pol", "Visina", 
                          "Težina", "Trka100m", "Skok udalj", "Čučnjevi"]

# %%
#ФОРМИРАЊЕ НОВОГ РЕДА

# %%
TabelaRezultata.loc["MINIMUM"] = ""

# %%
TabelaRezultata
# Out:
#         R. br.     Ime     Prezime Pol Visina Težina Trka100m Skok udalj  \
# 0            1     Una       Zorić   Ž    161     45    16.32       1.21
# 1            2   Marta  Stanojević   Ž    165     53    15.44       1.01
# 2            3  Ognjen   Novaković   M    171     64    14.56        1.1
# 3            4   Petra   Kaličanin   Ž    159     48    16.98       0.89
# 4            5   Novak    Đorđević   M    175     67    15.01       1.32
# 5            6   Đurđe      Martać   M    178     65    16.25       1.18
# 6            7  Kalina  Ognjenović   Ž    170     62    14.38       0.95
# 7            8   Vanja     Čolović   M    181     72    14.55       0.98
# MINIMUM
#
#         Čučnjevi
# 0             25
# 1             16
# 2              5
# 3             21
# 4             28
# 5             25
# 6             25
# 7             26
# MINIMUM

# %%
#ПОПУЊАВАЊЕ НОВОГ РЕДА

# %%
TabelaRezultata.loc["MINIMUM","Visina":"Čučnjevi"] = TabelaRezultata.iloc[:8, 4:].min()

# %%
TabelaRezultata
# Out:
#         R. br.     Ime     Prezime Pol Visina Težina Trka100m Skok udalj  \
# 0            1     Una       Zorić   Ž    161     45    16.32       1.21
# 1            2   Marta  Stanojević   Ž    165     53    15.44       1.01
# 2            3  Ognjen   Novaković   M    171     64    14.56        1.1
# 3            4   Petra   Kaličanin   Ž    159     48    16.98       0.89
# 4            5   Novak    Đorđević   M    175     67    15.01       1.32
# 5            6   Đurđe      Martać   M    178     65    16.25       1.18
# 6            7  Kalina  Ognjenović   Ž    170     62    14.38       0.95
# 7            8   Vanja     Čolović   M    181     72    14.55       0.98
# MINIMUM                                   159     45    14.38       0.89
#
#         Čučnjevi
# 0             25
# 1             16
# 2              5
# 3             21
# 4             28
# 5             25
# 6             25
# 7             26
# MINIMUM        5

# %% [markdown]
# **Slika 3.8.8. још редова и њихових података**

# %%
TabelaRezultata.loc["MAKSIMUM"]= ""
TabelaRezultata.loc["PROSEK"]= ""
TabelaRezultata.loc["ZBIR"]= ""
TabelaRezultata.loc["BROJ PODATAKA"]= ""

# %%
TabelaRezultata
# Out:
#               R. br.     Ime     Prezime Pol Visina Težina Trka100m  \
# 0                  1     Una       Zorić   Ž    161     45    16.32
# 1                  2   Marta  Stanojević   Ž    165     53    15.44
# 2                  3  Ognjen   Novaković   M    171     64    14.56
# 3                  4   Petra   Kaličanin   Ž    159     48    16.98
# 4                  5   Novak    Đorđević   M    175     67    15.01
# 5                  6   Đurđe      Martać   M    178     65    16.25
# 6                  7  Kalina  Ognjenović   Ž    170     62    14.38
# 7                  8   Vanja     Čolović   M    181     72    14.55
# MINIMUM                                         159     45    14.38
# MAKSIMUM
# PROSEK
# ZBIR
# BROJ PODATAKA
#
#               Skok udalj Čučnjevi
# 0                   1.21       25
# 1                   1.01       16
# 2                    1.1        5
# 3                   0.89       21
# 4                   1.32       28
# 5                   1.18       25
# ...

# %%
TabelaRezultata.loc["MAKSIMUM","Visina":"Čučnjevi"] = TabelaRezultata.iloc[0:8,4:].max()
TabelaRezultata.loc["PROSEK","Visina":"Čučnjevi"] = TabelaRezultata.iloc[0:8,4:].mean()
TabelaRezultata.loc["ZBIR","Visina":"Čučnjevi"] = TabelaRezultata.iloc[0:8,4:].sum()
TabelaRezultata.loc["BROJ PODATAKA","Visina":"Čučnjevi"] = TabelaRezultata.iloc[0:8,4:].count()

# %%
TabelaRezultata
# Out:
#               R. br.     Ime     Prezime Pol Visina Težina  Trka100m  \
# 0                  1     Una       Zorić   Ž    161     45     16.32
# 1                  2   Marta  Stanojević   Ž    165     53     15.44
# 2                  3  Ognjen   Novaković   M    171     64     14.56
# 3                  4   Petra   Kaličanin   Ž    159     48     16.98
# 4                  5   Novak    Đorđević   M    175     67     15.01
# 5                  6   Đurđe      Martać   M    178     65     16.25
# 6                  7  Kalina  Ognjenović   Ž    170     62     14.38
# 7                  8   Vanja     Čolović   M    181     72     14.55
# MINIMUM                                         159     45     14.38
# MAKSIMUM                                        181     72     16.98
# PROSEK                                        170.0   59.5  15.43625
# ZBIR                                           1360    476    123.49
# BROJ PODATAKA                                     8      8         8
#
# ...

# %%
#дом са стр. 199

# %%
import matplotlib.pyplot as plt

# %%
Polovi = TabelaRezultata["Pol"].value_counts()
Polovi
# Out:
#      5
# Ž    4
# M    4
# Name: Pol, dtype: int64

# %%
plt.pie(Polovi.values)
plt.title("Polovi", size=15)
plt.legend(Polovi.index, bbox_to_anchor=(1,0.75))
plt.show()
plt.close()

# %%
#dom sa str 187

# %%
TabelaRezultata.drop("PROSEK", axis=0, inplace=True)
TabelaRezultata
# Out:
#               R. br.     Ime     Prezime Pol Visina Težina Trka100m  \
# 0                  1     Una       Zorić   Ž    161     45    16.32
# 1                  2   Marta  Stanojević   Ž    165     53    15.44
# 2                  3  Ognjen   Novaković   M    171     64    14.56
# 3                  4   Petra   Kaličanin   Ž    159     48    16.98
# 4                  5   Novak    Đorđević   M    175     67    15.01
# 5                  6   Đurđe      Martać   M    178     65    16.25
# 6                  7  Kalina  Ognjenović   Ž    170     62    14.38
# 7                  8   Vanja     Čolović   M    181     72    14.55
# MINIMUM                                         159     45    14.38
# MAKSIMUM                                        181     72    16.98
# ZBIR                                           1360    476   123.49
# BROJ PODATAKA                                     8      8        8
#
#               Skok udalj Čučnjevi
# 0                   1.21       25
# ...

# %%
TabelaRezultata.drop("ZBIR", axis=0, inplace=True)
TabelaRezultata
# Out:
#               R. br.     Ime     Prezime Pol Visina Težina Trka100m  \
# 0                  1     Una       Zorić   Ž    161     45    16.32
# 1                  2   Marta  Stanojević   Ž    165     53    15.44
# 2                  3  Ognjen   Novaković   M    171     64    14.56
# 3                  4   Petra   Kaličanin   Ž    159     48    16.98
# 4                  5   Novak    Đorđević   M    175     67    15.01
# 5                  6   Đurđe      Martać   M    178     65    16.25
# 6                  7  Kalina  Ognjenović   Ž    170     62    14.38
# 7                  8   Vanja     Čolović   M    181     72    14.55
# MINIMUM                                         159     45    14.38
# MAKSIMUM                                        181     72    16.98
# BROJ PODATAKA                                     8      8        8
#
#               Skok udalj Čučnjevi
# 0                   1.21       25
# 1                   1.01       16
# 2                    1.1        5
# ...

# %%
TabelaRezultata.drop("Ime", axis=1, inplace=True)
TabelaRezultata
# Out:
#               R. br.     Prezime Pol Visina Težina Trka100m Skok udalj  \
# 0                  1       Zorić   Ž    161     45    16.32       1.21
# 1                  2  Stanojević   Ž    165     53    15.44       1.01
# 2                  3   Novaković   M    171     64    14.56        1.1
# 3                  4   Kaličanin   Ž    159     48    16.98       0.89
# 4                  5    Đorđević   M    175     67    15.01       1.32
# 5                  6      Martać   M    178     65    16.25       1.18
# 6                  7  Ognjenović   Ž    170     62    14.38       0.95
# 7                  8     Čolović   M    181     72    14.55       0.98
# MINIMUM                                 159     45    14.38       0.89
# MAKSIMUM                                181     72    16.98       1.32
# BROJ PODATAKA                             8      8        8          8
#
#               Čučnjevi
# 0                   25
# 1                   16
# 2                    5
# ...

# %%
TabelaRezultata.drop("Prezime", axis=1, inplace=True)
TabelaRezultata
# Out:
#               R. br. Pol Visina Težina Trka100m Skok udalj Čučnjevi
# 0                  1   Ž    161     45    16.32       1.21       25
# 1                  2   Ž    165     53    15.44       1.01       16
# 2                  3   M    171     64    14.56        1.1        5
# 3                  4   Ž    159     48    16.98       0.89       21
# 4                  5   M    175     67    15.01       1.32       28
# 5                  6   M    178     65    16.25       1.18       25
# 6                  7   Ž    170     62    14.38       0.95       25
# 7                  8   M    181     72    14.55       0.98       26
# MINIMUM                     159     45    14.38       0.89        5
# MAKSIMUM                    181     72    16.98       1.32       28
# BROJ PODATAKA                 8      8        8          8        8

# %%
TabelaRezultata.drop("Pol", axis=1, inplace=True)
TabelaRezultata
# Out:
#               R. br. Visina Težina Trka100m Skok udalj Čučnjevi
# 0                  1    161     45    16.32       1.21       25
# 1                  2    165     53    15.44       1.01       16
# 2                  3    171     64    14.56        1.1        5
# 3                  4    159     48    16.98       0.89       21
# 4                  5    175     67    15.01       1.32       28
# 5                  6    178     65    16.25       1.18       25
# 6                  7    170     62    14.38       0.95       25
# 7                  8    181     72    14.55       0.98       26
# MINIMUM                 159     45    14.38       0.89        5
# MAKSIMUM                181     72    16.98       1.32       28
# BROJ PODATAKA             8      8        8          8        8
