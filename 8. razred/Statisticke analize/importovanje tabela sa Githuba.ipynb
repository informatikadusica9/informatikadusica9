# %%
import pandas as pd

# %%
#fajlovi/Informatika i računarstvo 8/Zbirka zadataka za Jupyter Notebook/Mesecna potrosnja struje.csv

# %%
TabelaGT = pd.read_csv("https://raw.githubusercontent.com/vulkanznanje/fajlovi/master/Informatika%20i%20ra%C4%8Dunarstvo%208/Zbirka%20zadataka%20za%20Jupyter%20Notebook/Mesecna%20potrosnja%20struje.csv")

# %%
TabelaGT
# Out:
#               Uređaj  Snaga [W]  Prosečno vreme rada u toku dana [h]
# 0  Električni šporet       3000                                  2.0
# 1             Bojler       2000                                  2.0
# 2          Televizor        300                                  8.0
# 3      Mašina za veš       2000                                  2.0
# 4           Frižider        200                                  2.0
# 5       Klima uređaj       4000                                  2.0
# 6   Električna pegla       2000                                  1.0
# 7           Usisivač       1600                                  0.3
# 8            Računar        400                                  6.0

# %%
Gradovi= pd.read_csv("https://raw.githubusercontent.com/vulkanznanje/fajlovi/master/Informatika%20i%20ra%C4%8Dunarstvo%208/Zbirka%20zadataka%20za%20Jupyter%20Notebook/Gradovi.csv")

# %%
Gradovi
# Out:
#                  Grad  Površina  Uže područje  Šire područje
# 0             Beograd     360.0       1233796        1659440
# 1                 Bor     856.0         34016          48615
# 2               Čačak     636.0         73331         115337
# 3            Jagodina     470.0         37282          71852
# 4             Kikinda     782.5         38065          59453
# 5          Kragujevac     865.0        150835         179417
# 6            Kraljevo    1530.0         68749         125488
# 7            Kruševac     854.0         58745         128752
# 8            Leskovac    1025.0         60288         144206
# 9             Loznica     612.0         19212          79327
# 10                Niš     596.7        183164         260237
# 11         Novi Pazar     742.0         66527         100041
# 12           Novi Sad     702.7        277522         341625
# 13            Pančevo     759.0         76203         123414
# ...

# %%
Planine= pd.read_csv("https://raw.githubusercontent.com/vulkanznanje/fajlovi/master/Informatika%20i%20ra%C4%8Dunarstvo%208/Zbirka%20zadataka%20za%20Jupyter%20Notebook/Planine%20u%20Srbiji.csv")

# %%
Planine
# Out:
#         Planina            Vrh  Visina
# 0   Šar-planina       Crni vrh    2585
# 1   Šar-planina           Maja    2493
# 2     Koprivnik       Veternik    2461
# 3    Prokletije     Žuti kamen    2522
# 4   Šar-planina          Vrtop    2555
# ..          ...            ...     ...
# 82  Fruška Gora   Iriški Venac     451
# 83     Kopaonik  Suvo rudište     1976
# 84    Jastrebac     Bela stena    1257
# 85     Kopaonik  Markove stene    1721
# 86  Fruška Gora     Crveni čot     539
#
# [87 rows x 3 columns]

# %%
Reke= pd.read_csv("https://raw.githubusercontent.com/vulkanznanje/fajlovi/master/Informatika%20i%20ra%C4%8Dunarstvo%208/Zbirka%20zadataka%20za%20Jupyter%20Notebook/Reke%20u%20Srbiji.csv")

# %%
Reke
# Out:
#                     Reka  Dužina  Površina
# 0                  Dunav    2857    817000
# 1                   Tisa     965    157020
# 2                   Sava     990     95719
# 3          Velika Morava     185     35419
# 4                  Drina     346     19570
# 5                  Tamiš     359     13085
# 6                   Drim     335     11756
# 7           Južna Morava     295     15469
# 8               Kolubara     123      3639
# 9                   Uvac     119      1310
# 10               Zlatica     117      1470
# 11                 Karaš     110      1400
# 12               Krivaja     109       956
# 13                Rasina      92       994
# 14               Sitnica      90      3129
# 15               Tamnava      90       930
# 16            Pusta reka      71       569
# 17                Radika      70       665
# 18               Vlasina      68      1050
# 19                Resava      65       685
# 20        Pećka Bistrica      62       505
# ...

# %%
okruzi= pd.read_csv("https://raw.githubusercontent.com/vulkanznanje/fajlovi/master/Informatika%20i%20ra%C4%8Dunarstvo%208/Zbirka%20zadataka%20za%20Jupyter%20Notebook/Okruzi.csv")

# %%
okruzi
# Out:
#     R. Br.                   Okrug            Sedište  \
# 0        1              Beogradski            Beograd
# 1        2                  Borski                Bor
# 2        3             Braničevski          Požarevac
# 3        4              Jablanički           Leskovac
# 4        5       Južno-Bački okrug           Novi Sad
# 5        6    Južno-Banatski okrug            Pančevo
# 6        7              Kolubarski            Valjevo
# 7        8               Mačvanski              Šabac
# 8        9               Moravički              Čačak
# 9       10                Nišavski                Niš
# 10      11                Pčinjski             Vranje
# 11      12                Pirotski              Pirot
# 12      13              Podunavski          Smederevo
# 13      14              Pomoravski           Jagodina
# 14      15                Rasinski           Kruševac
# 15      16                   Raški           Kraljevo
# ...
