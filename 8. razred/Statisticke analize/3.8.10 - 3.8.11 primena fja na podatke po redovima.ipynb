# %%
import pandas as pd

# %%
Ocene = [[1, "Una",    "Zorić",       5, 4, 2, 3, 3],
         [2, "Marta",  "Stojanović",  5, 4, 5, 5, 4],
         [3, "Ognjen", "Novaković",   3, 4, 3, 4, 4],
         [4, "Petra",  "Kaličanin",   5, 5, 5, 5, 5],
         [5, "Novak",  "Đorđević",    2, 2, 2, 3, 3],
         [6, "Đurđe",  "Martać",      1, 1, 1, 3, 1],
         [7, "Kalina", "Ognjenović",  5, 5, 4, 4, 2],
         [8, "Vanja",  "Čolović",     5, 3, 5, 4, 2]]

# %%
TabOcene = pd.DataFrame(Ocene)
TabOcene.columns=["Rbr", "Ime", "Prezime", "Biologija", 
                  "Istorija", "Geografija", "Fizika", "Hemija"]

# %%
TabOcene
# Out:
#    Rbr     Ime     Prezime  Biologija  Istorija  Geografija  Fizika  Hemija
# 0    1     Una       Zorić          5         4           2       3       3
# 1    2   Marta  Stojanović          5         4           5       5       4
# 2    3  Ognjen   Novaković          3         4           3       4       4
# 3    4   Petra   Kaličanin          5         5           5       5       5
# 4    5   Novak    Đorđević          2         2           2       3       3
# 5    6   Đurđe      Martać          1         1           1       3       1
# 6    7  Kalina  Ognjenović          5         5           4       4       2
# 7    8   Vanja     Čolović          5         3           5       4       2

# %%
TabOcene["Prosek"]= ""

# %%
TabOcene
# Out:
#    Rbr     Ime     Prezime  Biologija  Istorija  Geografija  Fizika  Hemija  \
# 0    1     Una       Zorić          5         4           2       3       3
# 1    2   Marta  Stojanović          5         4           5       5       4
# 2    3  Ognjen   Novaković          3         4           3       4       4
# 3    4   Petra   Kaličanin          5         5           5       5       5
# 4    5   Novak    Đorđević          2         2           2       3       3
# 5    6   Đurđe      Martać          1         1           1       3       1
# 6    7  Kalina  Ognjenović          5         5           4       4       2
# 7    8   Vanja     Čolović          5         3           5       4       2
#
#   Prosek
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
TabOcene["Prosek"] = TabOcene.loc[:,"Biologija":"Hemija"].mean(axis = 1)

# %%
TabOcene
# Out:
#    Rbr     Ime     Prezime  Biologija  Istorija  Geografija  Fizika  Hemija  \
# 0    1     Una       Zorić          5         4           2       3       3
# 1    2   Marta  Stojanović          5         4           5       5       4
# 2    3  Ognjen   Novaković          3         4           3       4       4
# 3    4   Petra   Kaličanin          5         5           5       5       5
# 4    5   Novak    Đorđević          2         2           2       3       3
# 5    6   Đurđe      Martać          1         1           1       3       1
# 6    7  Kalina  Ognjenović          5         5           4       4       2
# 7    8   Vanja     Čolović          5         3           5       4       2
#
#    Prosek
# 0     3.4
# 1     4.6
# 2     3.6
# 3     5.0
# 4     2.4
# 5     1.4
# 6     4.0
# 7     3.8

# %%
#ДОМ СА СТР 186 uraditi prosek na nivou celog razreda

# %%
TabOcene.loc["UKPROSEK"]= ""

# %%
TabOcene.loc["UKPROSEK","Prosek"] =round(TabOcene.iloc[0:8,-1].mean(),1)
TabOcene
# Out:
#          Rbr     Ime     Prezime Biologija Istorija Geografija Fizika Hemija  \
# 0          1     Una       Zorić         5        4          2      3      3
# 1          2   Marta  Stojanović         5        4          5      5      4
# 2          3  Ognjen   Novaković         3        4          3      4      4
# 3          4   Petra   Kaličanin         5        5          5      5      5
# 4          5   Novak    Đorđević         2        2          2      3      3
# 5          6   Đurđe      Martać         1        1          1      3      1
# 6          7  Kalina  Ognjenović         5        5          4      4      2
# 7          8   Vanja     Čolović         5        3          5      4      2
# UKPROSEK
#
#          Prosek
# 0           3.4
# 1           4.6
# 2           3.6
# 3           5.0
# 4           2.4
# 5           1.4
# 6           4.0
# 7           3.8
# UKPROSEK    3.5

# %%
#БРИСАЊЕ РЕДОВА ИЗ ТАБЕЛЕ  / 6. reda

# %%
TabOcene.drop(6, axis=0, inplace=True)
TabOcene
# Out:
#          Rbr     Ime     Prezime Biologija Istorija Geografija Fizika Hemija  \
# 0          1     Una       Zorić         5        4          2      3      3
# 1          2   Marta  Stojanović         5        4          5      5      4
# 2          3  Ognjen   Novaković         3        4          3      4      4
# 3          4   Petra   Kaličanin         5        5          5      5      5
# 4          5   Novak    Đorđević         2        2          2      3      3
# 5          6   Đurđe      Martać         1        1          1      3      1
# 7          8   Vanja     Čolović         5        3          5      4      2
# UKPROSEK
#
#          Prosek
# 0           3.4
# 1           4.6
# 2           3.6
# 3           5.0
# 4           2.4
# 5           1.4
# 7           3.8
# UKPROSEK    3.5

# %%
#БРИСАЊЕКОЛОНА ИЗ ТАБЕЛЕ  /I kolone RBR

# %%
TabOcene.drop("Rbr", axis=1, inplace=True)
TabOcene
# Out:
#              Ime     Prezime Biologija Istorija Geografija Fizika Hemija  \
# 0            Una       Zorić         5        4          2      3      3
# 1          Marta  Stojanović         5        4          5      5      4
# 2         Ognjen   Novaković         3        4          3      4      4
# 3          Petra   Kaličanin         5        5          5      5      5
# 4          Novak    Đorđević         2        2          2      3      3
# 5          Đurđe      Martać         1        1          1      3      1
# 7          Vanja     Čolović         5        3          5      4      2
# UKPROSEK
#
#          Prosek
# 0           3.4
# 1           4.6
# 2           3.6
# 3           5.0
# 4           2.4
# 5           1.4
# 7           3.8
# UKPROSEK    3.5

# %%
#transponovanje tabele/ okretanje

# %%
TabOcene.T
# Out:
#                 0           1          2          3         4       5  \
# Ime           Una       Marta     Ognjen      Petra     Novak   Đurđe
# Prezime     Zorić  Stojanović  Novaković  Kaličanin  Đorđević  Martać
# Biologija       5           5          3          5         2       1
# Istorija        4           4          4          5         2       1
# Geografija      2           5          3          5         2       1
# Fizika          3           5          4          5         3       3
# Hemija          3           4          4          5         3       1
# Prosek        3.4         4.6        3.6        5.0       2.4     1.4
#
#                   7 UKPROSEK
# Ime           Vanja
# Prezime     Čolović
# Biologija         5
# Istorija          3
# Geografija        5
# Fizika            4
# Hemija            2
# Prosek          3.8      3.5
