# %%
#kreiranje ugnježđene liste Rezultati
Rezultati = [[1, "Una",    "Zorić",      16.32, 1.21, 25],
             [2, "Marta",  "Stanojević", 15.44, 1.01, 16],
             [3, "Ognjen", "Novaković",  14.56, 1.10, 5],
             [4, "Petra",  "Kaličanin",  16.98, 0.89, 21],
             [5, "Novak",  "Đorđević",   15.01, 1.32, 28],
             [6, "Đurđe",  "Martać",     16.25, 1.18, 25],
             [7, "Kalina", "Ognjenović", 14.38, 0.95, 25],
             [8, "Vanja",  "Čolović",    14.55, 0.98, 26]]

# %% [markdown]
# #DEFINISANJE TABELE PREKO DATAFRAME

# %%
#uvoz biblioteke pandas
import pandas as pd

# %%
#pravljenje tabele od ugnježđene liste
TabelaRezultata = pd.DataFrame(Rezultati)

# %%
#prikaz kreirane tabele
TabelaRezultata
# Out:
#    0       1           2      3     4   5
# 0  1     Una       Zorić  16.32  1.21  25
# 1  2   Marta  Stanojević  15.44  1.01  16
# 2  3  Ognjen   Novaković  14.56  1.10   5
# 3  4   Petra   Kaličanin  16.98  0.89  21
# 4  5   Novak    Đorđević  15.01  1.32  28
# 5  6   Đurđe      Martać  16.25  1.18  25
# 6  7  Kalina  Ognjenović  14.38  0.95  25
# 7  8   Vanja     Čolović  14.55  0.98  26

# %%
#dodeljivanje naziva kolonama
TabelaRezultata.columns = ["R. br.", "Ime", "Prezime", "Trka100m", "Skok udalj", "Čučnjevi"]

# %%
TabelaRezultata
# Out:
#    R. br.     Ime     Prezime  Trka100m  Skok udalj  Čučnjevi
# 0       1     Una       Zorić     16.32        1.21        25
# 1       2   Marta  Stanojević     15.44        1.01        16
# 2       3  Ognjen   Novaković     14.56        1.10         5
# 3       4   Petra   Kaličanin     16.98        0.89        21
# 4       5   Novak    Đorđević     15.01        1.32        28
# 5       6   Đurđe      Martać     16.25        1.18        25
# 6       7  Kalina  Ognjenović     14.38        0.95        25
# 7       8   Vanja     Čolović     14.55        0.98        26

# %% [markdown]
# **Čuvanje tabele u različitim formatima**

# %%
TabelaRezultata.to_csv("Takmičenje.csv")

# %%
TabelaRezultata.to_csv("Takmicenje.csv", index=False)

# %%
TabelaRezultata.to_csv("T.csv", index=False, encoding = "utf-8-sig")

# %%
TabelaRezultata.to_excel("Takmicenje.xlsx", index=False)

# %%
TabelaRezultata.to_csv("Takmicenje.txt", index=False)

# %%
#TabelaRezultata.to_csv("C:/Users/Ucenik/Desktop/Takmičenje.csv", index=False)

# %% [markdown]
# **Učitavanje tabela iz fajlova s računara i s interneta**

# %%
TabelaOcena = pd.read_csv("T.csv")

# %%
TabelaOcena
# Out:
#    R. br.     Ime     Prezime  Trka100m  Skok udalj  Čučnjevi
# 0       1     Una       Zorić     16.32        1.21        25
# 1       2   Marta  Stanojević     15.44        1.01        16
# 2       3  Ognjen   Novaković     14.56        1.10         5
# 3       4   Petra   Kaličanin     16.98        0.89        21
# 4       5   Novak    Đorđević     15.01        1.32        28
# 5       6   Đurđe      Martać     16.25        1.18        25
# 6       7  Kalina  Ognjenović     14.38        0.95        25
# 7       8   Vanja     Čolović     14.55        0.98        26

# %% [markdown]
# Kad se kopira adresa fajla mora da se promene kose crte - ne sme \, mora /

# %%
TabelaOcenaXL = pd.read_excel("C:/Users/Desktop/Downloads/Ocene.xlsx")

# %%
TabelaOcenaXL
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN     Р. бр.        Име     Презиме  Биологија   Историја
# 1         NaN          1        Уна       Зорић          5          4
# 2         NaN          2      Марта  Стојановић          5          5
# 3         NaN          3      Огњен   Новаковић          5          5
# 4         NaN          4      Петра   Каличанин          5          5
# 5         NaN          5      Новак    Ђорђевић          3          3
# 6         NaN          6      Ђурђе      Мартаћ          4          5
# 7         NaN          7     Калина   Огњеновић          5          3
# 8         NaN          8       Вања     Чоловић          5          5
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0  Географија     Физика     Хемија
# 1           5          3          3
# 2           5          5          5
# 3           5          4          4
# 4           4          5          5
# 5           4          3          3
# 6           3          3          4
# 7           4          4          4
# 8           5          4          5

# %% [markdown]
# mora da se klikne na row i kopira se adresa

# %%
TabelaGT = pd.read_csv("https://raw.githubusercontent.com/vulkanznanje/fajlovi/master/Informatika%20i%20ra%C4%8Dunarstvo%208/Zbirka%20zadataka%20za%20Jupyter%20Notebook/Ocene.csv")

# %%
TabelaGT
# Out:
#    Rbr     Ime     Prezime  Biologija  Istorija  Geografija  Fizika  Hemija
# 0    1     Una       Zorić          5         4           2       3       3
# 1    2   Marta  Stojanović          5         4           5       5       4
# 2    3  Ognjen   Novaković          3         4           3       4       4
# 3    4   Petra   Kaličanin          5         5           5       5       5
# 4    5   Novak    Đorđević          2         2           2       3       3
# 5    6   Đurđe      Martać          1         1           1       3       1
# 6    7  Kalina  Ognjenović          5         5           4       4       2
# 7    8   Vanja     Čolović          5         3           5       4       2
